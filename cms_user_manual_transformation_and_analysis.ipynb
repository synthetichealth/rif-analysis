# %% [markdown]
# # Use the code below to load the data

# %%
# import pandas library
import pandas as pd

# %%
# load data
# note: Each file except for dme and beneficiary_YYYY contain mixed data types. 
# to prevent DtypeWarning, specify dtype option on import or set low_memory=False as shown below.

synthetic_bene_df = pd.read_csv('data/beneficiary_2022.csv', sep="|", low_memory=False)
synthetic_inpatient_df = pd.read_csv('data/inpatient.csv',  sep="|", low_memory=False)
synthetic_outpatient_df = pd.read_csv('data/outpatient.csv', sep="|",low_memory=False)
synthetic_carrier_df = pd.read_csv('data/carrier.csv', sep="|", low_memory=False)
synthetic_hha_df = pd.read_csv('data/hha.csv', sep="|", low_memory=False)
synthetic_hospice_df = pd.read_csv('data/hospice.csv', sep="|", low_memory=False)
synthetic_hospice_df = pd.read_csv('data/dme.csv', sep="|", low_memory=False)
synthetic_snf_df = pd.read_csv('data/snf.csv', sep="|", low_memory=False)

# %% [markdown]
# ______________________________________________________________________________________________________________________

# %%
# note: Each file consists of many columns. 
# if you would like to limit the columns loaded into a particular dataframe, input the 'usecols' parameter argument which is specific to the read_csv function in the pandas library.

synthetic_inpatient_df_spec_cols = pd.read_csv('data/inpatient.csv', 
usecols=['BENE_ID','CLM_ID','CLM_ADMSN_DT','NCH_BENE_DSCHRG_DT','PRNCPAL_DGNS_CD'], 
sep="|")

synthetic_inpatient_df_spec_cols
# Out:
#               BENE_ID          CLM_ID CLM_ADMSN_DT NCH_BENE_DSCHRG_DT  \
# 0     -10000010254618 -10000930037831  25-Mar-2015        25-Mar-2015
# 1     -10000010254653 -10000930038030  24-Sep-2015        24-Sep-2015
# 2     -10000010254653 -10000930038031  09-May-2017        10-May-2017
# 3     -10000010254656 -10000930038162  14-Jan-2017        14-Jan-2017
# 4     -10000010254656 -10000930038162  14-Jan-2017        14-Jan-2017
# ...               ...             ...          ...                ...
# 58061 -10000010288008 -10000931485965  08-Jan-2020        14-Jan-2020
# 58062 -10000010288008 -10000931485967  23-Oct-2020        23-Oct-2020
# 58063 -10000010288008 -10000931485969  22-Aug-2021        23-Aug-2021
# 58064 -10000010288008 -10000931485971  13-Sep-2021        16-Sep-2021
# 58065 -10000010288010 -10000931486024  11-Jun-2017        11-Jun-2017
#
#       PRNCPAL_DGNS_CD
# 0              S134XX
# 1               Z3480
# 2              T7432X
# 3              S8290X
# 4              S8290X
# ...               ...
# 58061         T50901A
# 58062         T50901A
# 58063         T50901A
# 58064         T50901A
# 58065          S93409
#
# [58066 rows x 5 columns]
