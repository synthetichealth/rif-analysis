# %% [markdown]
# # Use this code to load the data

# %%
# import pandas library
import pandas as pd

# %%
# load csv files
synthetic_bene_df = pd.read_csv('data/beneficiary_final.csv', sep="|")

synthetic_inpatient_df = pd.read_csv('data/inpatient.csv',  sep="|", low_memory=False)

synthetic_outpatient_df = pd.read_csv('data/outpatient.csv', sep="|",low_memory=False)

synthetic_carrier_df = pd.read_csv('data/carrier.csv', sep="|", low_memory=False)

synthetic_dme_df = pd.read_csv('data/dme.csv', sep="|")

synthetic_hha_df = pd.read_csv('data/hha.csv', sep="|", low_memory=False)

synthetic_hospice_df = pd.read_csv('data/hospice.csv', sep="|", low_memory=False)

synthetic_snf_df = pd.read_csv('data/snf.csv', sep="|", low_memory=False)

# %% [markdown]
# ______________________________________________________________________________________________________________________

# %% [markdown]
# # More information on loading the data

# %%
# Each file except for dme and beneficiary contain mixed data types. 
# To prevent DtypeWarning, specify dtype option on import or set low_memory=False as shown below.

synthetic_inpatient_df = pd.read_csv('data/inpatient.csv',  sep="|", low_memory=False)
synthetic_outpatient_df = pd.read_csv('data/outpatient.csv', sep="|",low_memory=False)
synthetic_carrier_df = pd.read_csv('data/carrier.csv', sep="|", low_memory=False)
synthetic_hha_df = pd.read_csv('data/hha.csv', sep="|", low_memory=False)
synthetic_hospice_df = pd.read_csv('data/hospice.csv', sep="|", low_memory=False)
synthetic_snf_df = pd.read_csv('data/snf.csv', sep="|", low_memory=False)

# %%
# Each file consists of many columns. 
# If you would like to limit the columns loaded into a particular dataframe, input the 'usecols' parameter argument which is specific to the read_csv function in the pandas library.

synthetic_inpatient_df_spec_cols = pd.read_csv('data/inpatient.csv', 
usecols=['BENE_ID','CLM_ID','CLM_ADMSN_DT','NCH_BENE_DSCHRG_DT','PRNCPAL_DGNS_CD'], 
sep="|")

synthetic_inpatient_df_spec_cols
# Out:
#               BENE_ID          CLM_ID CLM_ADMSN_DT NCH_BENE_DSCHRG_DT  \
# 0     -10000000010001 -10000003175478  14-Jun-2015        15-Jun-2015
# 1     -10000000010001 -10000003175479  21-Jun-2015        22-Jun-2015
# 2     -10000000010001 -10000003175480  14-Jul-2015        15-Jul-2015
# 3     -10000000010001 -10000003175481  04-Aug-2015        05-Aug-2015
# 4     -10000000010001 -10000003175482  26-Aug-2015        27-Aug-2015
# ...               ...             ...          ...                ...
# 39118 -10000000019997 -10000003945613  24-Oct-2012        24-Oct-2012
# 39119 -10000000019997 -10000003945614  09-Apr-2019        09-Apr-2019
# 39120 -10000000019997 -10000003945615  15-Mar-2020        15-Mar-2020
# 39121 -10000000019998 -10000003945673  24-May-2016        24-May-2016
# 39122 -10000000019999 -10000003945749  10-Jul-2018        10-Jul-2018
#
#       PRNCPAL_DGNS_CD
# 0              C50919
# 1              C50929
# 2              C50929
# 3              C50919
# 4              C50919
# ...               ...
# 39118            P292
# 39119            P292
# 39120             I10
# 39121             P90
# 39122             I10
#
# [39123 rows x 5 columns]
